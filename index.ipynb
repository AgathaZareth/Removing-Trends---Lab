# %% [markdown]
# # Removing Trends - Lab
#
# ## Introduction
#
# In this lab, you'll practice your detrending skills!
#
# ## Objectives
#
# In this lab you will:
#
# - Use a log transformation to minimize non-stationarity
# - Use rolling means to reduce non-stationarity
# - Use differencing to reduce non-stationarity
# - Use rolling statistics as a check for stationarity
# - Create visualizations of transformed time series as a visual aid to determine if stationarity has been achieved
# - Use the Dickey-Fuller test and conclude whether or not a dataset is exhibiting stationarity

# %% [markdown]
# ## Detrending the Air passenger data
#
# In this lab you will work with the air passenger dataset available in `'passengers.csv'`. First, run the following cell to import the necessary libraries.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# - Import the `'passengers.csv'` dataset
# - Change the data type of the `'Month'` column to a proper date format
# - Set the `'Month'` column as the index of the DataFrame
# - Print the first five rows of the dataset

# %%
# Import 'passengers.csv' dataset
data = pd.read_csv('passengers.csv')

# Change the data type of the 'Month' column
data['Month'] = pd.to_datetime(data['Month'])

# Set the 'Month' column as the index
ts = data.set_index('Month')

# Print the first five rows
ts.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %% [markdown]
# Plot this time series.

# %%
# Plot the time series
ts.plot(figsize=(15,5));

# %% [markdown]
# ## Create a stationarity check
#
# Your next task is to use the code from previous labs to create a function `stationarity_check()` that takes in a time series and performs stationarity checks including rolling statistics and the Dickey-Fuller test.
#
# We want the output of the function to:
#
# - Plot the original time series along with the rolling mean and rolling standard deviation (use a window of 8) in one plot
# - Output the results of the Dickey-Fuller test

# %%
# Create a function to check for the stationarity of a given time series using rolling stats and DF test
# Collect and package the code from previous labs

def stationarity_check(df, n_window=8):
    # Determine rolling statistics
    roll_mean = df.rolling(window=n_window, center=False).mean()
    roll_std = df.rolling(window=n_window, center=False).std()
    
    # Plot rolling statistics
    fig = plt.figure(figsize=(15,5)) #set up fig

    plt.plot(df, color='blue', label='Original')                  # plot the original curve
    plt.plot(roll_mean, color='red', label='Rolling Mean')        # plot the rolling mean
    plt.plot(roll_std, color='black', label='Rolling Standard D') # plot the rolling standard error

    plt.title('Rolling Mean & Standard Deviation')
    plt.legend();
    
    # Dickey-Fuller test
    from statsmodels.tsa.stattools import adfuller

    dftest = adfuller(df)

    # Extract and display test results in a user friendly manner
    dfoutput = pd.Series(dftest[0:4], 
                         index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value

    print ('Results of Dickey-Fuller test: \n')

    print(dfoutput)

# %% [markdown]
# Use your newly created function on the `ts` timeseries.

# %%
# Code here
stationarity_check(ts)
# Out:
# Results of Dickey-Fuller test:
#
# Test Statistic                   0.815369
# p-value                          0.991880
# #Lags Used                      13.000000
# Number of Observations Used    130.000000
# Critical Value (1%)             -3.481682
# Critical Value (5%)             -2.884042
# Critical Value (10%)            -2.578770
# dtype: float64

# %% [markdown]
# ## Perform a log and square root transform
#
# Plot a log transform of the original time series (`ts`).

# %%
# Plot a log transform
#stationarity_check(np.log(ts)) 
fig = plt.figure(figsize=(12,6))
plt.plot(np.log(ts), color='blue');

# %% [markdown]
# Plot a square root  transform of the original time series (`ts`).

# %%
# Plot a square root transform
#stationarity_check(np.sqrt(ts))
fig = plt.figure(figsize=(12,6))
plt.plot(np.sqrt(ts), color='blue');

# %% [markdown]
# Going forward, let's keep working with the log transformed data before subtracting rolling mean, differencing, etc.

# %% [markdown]
# ## Subtracting the rolling mean

# %% [markdown]
# Create a rolling mean using your log transformed time series, with a time window of 7. Plot the log-transformed time series and the rolling mean together.

# %%
# your code here
roll_mean = np.log(ts).rolling(window=7, center=False).mean()
fig = plt.figure(figsize=(11,7)) 

plt.plot(np.log(ts), color='blue', label='Log Transformed')       # plot the Log curve
plt.plot(roll_mean, color='red', label='Rolling Mean')            # plot the rolling mean

plt.title('Rolling Mean & Log Transformed Data')
plt.legend();

# %% [markdown]
# Now, subtract this rolling mean from the log transformed time series, and look at the 10 first elements of the result.

# %%
# Subtract the moving average from the log transformed data
data_minus_roll_mean = np.log(ts) - roll_mean

# Print the first 10 rows
data_minus_roll_mean.head(10)
# Out:
#             #Passengers
# Month
# 1949-01-01          NaN
# 1949-02-01          NaN
# 1949-03-01          NaN
# 1949-04-01          NaN
# 1949-05-01          NaN
# 1949-06-01          NaN
# 1949-07-01     0.150059
# 1949-08-01     0.110242
# 1949-09-01     0.005404
# 1949-10-01    -0.113317

# %% [markdown]
# Drop the missing values from this time series.

# %%
# Drop the missing values
data_minus_roll_mean.dropna(inplace=True)

data_minus_roll_mean.head()
# Out:
#             #Passengers
# Month
# 1949-07-01     0.150059
# 1949-08-01     0.110242
# 1949-09-01     0.005404
# 1949-10-01    -0.113317
# 1949-11-01    -0.217275

# %% [markdown]
# Plot this time series now.

# %%
# Plot the result
fig = plt.figure(figsize=(11,7))

plt.plot(data_minus_roll_mean, color='blue',label='Sales - rolling mean')

plt.title('Sales while the rolling mean is subtracted')

plt.legend();

# %% [markdown]
# Finally, use your function `check_stationarity()` to see if this series is stationary!

# %%
# Your code here
stationarity_check(data_minus_roll_mean)
# Out:
# Results of Dickey-Fuller test:
#
# Test Statistic                  -2.348027
# p-value                          0.156946
# #Lags Used                      14.000000
# Number of Observations Used    123.000000
# Critical Value (1%)             -3.484667
# Critical Value (5%)             -2.885340
# Critical Value (10%)            -2.579463
# dtype: float64

# %% [markdown]
# ### Based on the visuals and on the Dickey-Fuller test, what do you conclude?

# %%
# Your conclusion here
# p value is greater than 0.05 so the time series is not stationary.

# %%
#####

import datetime as dt
from scipy import stats
import math

slope_df = roll_mean.dropna().reset_index()
slope_df['Month'] =pd.to_datetime(slope_df['Month'])
slope_df['date_ordinal'] = pd.to_datetime(slope_df['Month']).map(dt.datetime.toordinal)
slope, intercept, r_value, p_value, std_err = stats.linregress(slope_df['date_ordinal'], slope_df['#Passengers'])
slope
math.isclose(slope,0, rel_tol=1e-09, abs_tol=0.00001)
#####
# Out:
# False

# %% [markdown]
# ## Subtracting the weighted rolling mean

# %% [markdown]
# Repeat all the above steps to calculate the exponential *weighted* rolling mean with a halflife of 4. Start from the log-transformed data again. Compare the Dickey-Fuller test results. What do you conclude?

# %%
data = np.log(ts)

# Calculate Weighted Moving Average of log transformed data
exp_roll_mean = data.ewm(halflife=4).mean()

# Plot the original data with exp weighted average
fig = plt.figure(figsize=(12,7))
orig = plt.plot(data, color='blue',label='Original')
mean = plt.plot(exp_roll_mean, color='red', label='Exponentially Weighted Rolling Mean')
plt.legend(loc='best')
plt.title('Exponentially Weighted Rolling Mean & Standard Deviation')
plt.show(block=False)

# %% [markdown]
# - Subtract this exponential weighted rolling mean from the log transformed data
# - Print the resulting time series

# %%
# Subtract the exponential weighted rolling mean from the original data 
data_minus_exp_roll_mean = data - exp_roll_mean

# Plot the time series
fig = plt.figure(figsize=(11,7))
plt.plot(data_minus_exp_roll_mean, color='blue',label='Passengers - weighted rolling mean')
plt.legend();

# %% [markdown]
# Check for stationarity of `data_minus_exp_roll_mean` using your function.

# %%
# Do a stationarity check
stationarity_check(data_minus_exp_roll_mean)
# Out:
# Results of Dickey-Fuller test:
#
# Test Statistic                  -3.297250
# p-value                          0.015002
# #Lags Used                      13.000000
# Number of Observations Used    130.000000
# Critical Value (1%)             -3.481682
# Critical Value (5%)             -2.884042
# Critical Value (10%)            -2.578770
# dtype: float64

# %% [markdown]
# ### Based on the visuals and on the Dickey-Fuller test, what do you conclude?

# %%
# Your conclusion here
# p value is less than 0.05 so the time series is  stationary.
# There are regular intervals of seasonality

# %%
#####

import datetime as dt
from scipy import stats
import math

slope_df = data_minus_exp_roll_mean.dropna().reset_index()
slope_df['Month'] =pd.to_datetime(slope_df['Month'])
slope_df['date_ordinal'] = pd.to_datetime(slope_df['Month']).map(dt.datetime.toordinal)
slope, intercept, r_value, p_value, std_err = stats.linregress(slope_df['date_ordinal'], slope_df['#Passengers'])
print(slope)

math.isclose(slope,0, rel_tol=1e-09, abs_tol=0.00001)

#####
# Out:
# -1.5666565149157159e-06
# True

# %% [markdown]
# ## Differencing

# %% [markdown]
# Using exponentially weighted moving averages, we seem to have removed the upward trend, but not the seasonality issue. Now use differencing to remove seasonality. Make sure you use the right amount of `periods`. Start from the log-transformed, exponentially weighted rolling mean-subtracted series.
#
# After you differenced the series, drop the missing values, plot the resulting time series, and then run the `stationarity check()` again.

# %%
# Difference your data
data_diff = data_minus_exp_roll_mean.diff(periods=12)

# Drop the missing values
data_diff.dropna(inplace=True)

# Check out the first few rows
data_diff.head(15)
# Out:
#             #Passengers
# Month
# 1950-01-01    -0.063907
# 1950-02-01    -0.001185
# 1950-03-01     0.029307
# 1950-04-01     0.016168
# 1950-05-01     0.000194
# 1950-06-01     0.062669
# 1950-07-01     0.095524
# 1950-08-01     0.085827
# 1950-09-01     0.081834
# 1950-10-01     0.032363
# 1950-11-01     0.005065
# 1950-12-01     0.069320
# 1951-01-01     0.107890
# 1951-02-01     0.042702
# 1951-03-01     0.086617

# %%
data_diff.plot(figsize=(15,5)); # wow, use .plot() to quickly plot a pandas df

# %% [markdown]
# Plot the resulting differenced time series.

# %%
# Plot your differenced time series
fig = plt.figure(figsize=(15,5))
plt.title('Differenced sales series')

plt.plot(data_diff, color='blue',label='Sales - rolling mean')

plt.legend();

# %%
# Perform the stationarity check
stationarity_check(data_diff)
# Out:
# Results of Dickey-Fuller test:
#
# Test Statistic                  -3.601666
# p-value                          0.005729
# #Lags Used                      12.000000
# Number of Observations Used    119.000000
# Critical Value (1%)             -3.486535
# Critical Value (5%)             -2.886151
# Critical Value (10%)            -2.579896
# dtype: float64

# %% [markdown]
# ### Your conclusion

# %%
# Your conclusion here
# P value in less that .05 so it is stationary, seasonality has been removed and the flucuations are random


"""
Even though the rolling mean and rolling average lines do seem to be fluctuating, 
the movements seem to be completely random, 
and the same conclusion holds for the original time series. 
Your time series is now ready for modeling!
"""

# %% [markdown]
# ## Summary
#
# In this lab, you learned how to make time series stationary through using log transforms, rolling means, and differencing.
